# %%
# Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Cleansing

# %%
# Importing Data as a Dataframe
df = pd.read_csv("ds_salaries.csv")

# Previewing Data
df.sample(10)
# Out:
#       work_year experience_level employment_type           job_title  salary  \
# 2550       2022               SE              FT       Data Engineer  130000
# 938        2023               SE              FT      Data Scientist  225000
# 471        2022               EN              FT       Data Engineer   57000
# 2154       2022               SE              FT       Data Engineer  175000
# 1214       2023               SE              FT        Data Analyst  108000
# 2619       2022               SE              FT  Analytics Engineer  120000
# 2813       2022               SE              FT  Analytics Engineer  140000
# 819        2023               MI              FT  Research Scientist  125000
# 2016       2022               SE              FT        Data Analyst  110600
# 365        2023               MI              FT        Data Analyst   90000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 2550             USD         130000                 US             0
# 938              USD         225000                 US             0
# 471              EUR          59888                 NL           100
# 2154             USD         175000                 US             0
# 1214             USD         108000                 US             0
# 2619             USD         120000                 US             0
# 2813             USD         140000                 US           100
# 819              USD         125000                 US           100
# 2016             USD         110600                 US             0
# 365              USD          90000                 US             0
#
#      company_location company_size
# 2550               US            M
# 938                US            M
# 471                NL            L
# 2154               US            M
# 1214               US            M
# 2619               US            M
# 2813               US            M
# 819                US            M
# 2016               US            M
# 365                US            M

# %% [markdown]
# We have 11 columns, including:
# - 4 numerical column (work_year, salary, salary_in_usd, and remote_ratio)
# - 7 categorical column (experience_level, employment_type, job_title, salary_currency, employee_residence, company_location, company_size)

# %% [markdown]
# ## Data Type

# %%
# Checking Data Type
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %% [markdown]
# The datatype is correct

# %% [markdown]
# ## Missing Values

# %%
# Checking Missing Values
df.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
# Checking Null Values
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# No missing values, no null values.

# %% [markdown]
# # Wrangling

# %% [markdown]
# ## Column Interpretation
#
# - work_year: The year the salary was paid
# - experience_level: The experience level in the job during the year
# - employment_type: The type of employment for the role
# - job_title: The role worked in during the year
# - salary: The total gross salary amount paid
# - salary_currency: The currency of the salary paid as an ISO 4217 currency code
# - salaryinusd: The salary in USD
# - employee_residence: Employee's primary country of residence in during the work year as an ISO 3166 country code
# - remote_ratio: The overall amount of work done remotely
# - company_location: The country of the employer's main office or contracting branch
# - company_size: The median number of people that worked for the company during the year
#
# Source: https://www.kaggle.com/datasets/arnabchaki/data-science-salaries-2023

# %%
df.sample(5)
# Out:
#       work_year experience_level employment_type           job_title  salary  \
# 1094       2023               SE              FT       Data Engineer  210000
# 3653       2021               SE              FT  Research Scientist  120500
# 976        2023               SE              FT        Data Analyst  130000
# 3194       2022               SE              FT       Data Engineer  183600
# 1026       2023               SE              FT       Data Engineer  139500
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1094             USD         210000                 US           100
# 3653             CAD          96113                 CA            50
# 976              USD         130000                 US           100
# 3194             USD         183600                 US           100
# 1026             USD         139500                 US             0
#
#      company_location company_size
# 1094               US            M
# 3653               CA            L
# 976                US            M
# 3194               US            L
# 1026               US            M

# %% [markdown]
# ### experience_level

# %%
df['experience_level'].unique()
# Out:
# array(['SE', 'MI', 'EN', 'EX'], dtype=object)

# %%
# description in experience_level is not describing the level clearly, so we need to redescribe the records
level = {'EN':'Junior', 'MI':'Intermediate', 'SE':'Senior', 'EX':'Executive'}
df['experience_level'] = df['experience_level'].map(level)

# or use this as alternative command
#df.replace({'experience_level':{'EN':'Junior', 'MI':'Intermediate', 'SE':'Senior', 'EX':'Executive'}} ,inplace =True)

# see the df
df.sample(5)
# Out:
#       work_year experience_level employment_type             job_title  \
# 1132       2023           Senior              FT  Data Science Manager
# 3735       2021           Junior              PT          AI Scientist
# 2725       2022           Senior              FT        Data Scientist
# 1302       2023        Executive              FT         Data Engineer
# 1825       2022           Senior              FT         Data Engineer
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1132  245100             USD         245100                 US             0
# 3735   12000             USD          12000                 BR           100
# 2725  236900             USD         236900                 US           100
# 1302  210914             USD         210914                 US           100
# 1825  106800             USD         106800                 US             0
#
#      company_location company_size
# 1132               US            M
# 3735               US            S
# 2725               US            L
# 1302               US            M
# 1825               US            M

# %% [markdown]
# ### employment_type

# %%
df['employment_type'].unique()
# Out:
# array(['FT', 'CT', 'FL', 'PT'], dtype=object)

# %%
# description in employment_type is not describing the level clearly, so we need to redescribe the records
emp_type = {'FT': 'Full-Time', 'PT':'Part-Time', 'FL': 'Freelance', 'CT': 'Contract'}
df['employment_type'] = df['employment_type'].map(emp_type)

# see the df
df.sample(5)
# Out:
#       work_year experience_level employment_type                  job_title  \
# 384        2023           Senior       Full-Time              Data Engineer
# 1784       2023           Senior       Full-Time             Data Architect
# 2065       2022           Senior       Full-Time             Data Scientist
# 2006       2022           Senior       Full-Time  Machine Learning Engineer
# 945        2023           Senior       Full-Time               Data Analyst
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 384   160000             USD         160000                 US             0
# 1784  174500             USD         174500                 US             0
# 2065  165000             USD         165000                 US             0
# 2006  201000             USD         201000                 US           100
# 945    90000             USD          90000                 US           100
#
#      company_location company_size
# 384                US            M
# 1784               US            M
# 2065               US            M
# 2006               US            M
# 945                US            M

# %% [markdown]
# ### remote_ratio

# %%
df.remote_ratio.unique()
# Out:
# array([100,   0,  50], dtype=int64)

# %%
# although remote ratio has number datatype, it is in fact a categorical data
# we need to redescribe the records
ratio = {100:'Fully-remote', 50:'Partially-remote', 0:'No-remote'}
[df['remote_ratio'] = df['remote_ratio'].map(ratio)

# see the df
df.sample(5)
# Out:
#       work_year experience_level employment_type                   job_title  \
# 1981       2022           Senior       Full-Time              Data Scientist
# 2150       2022     Intermediate       Full-Time              Data Scientist
# 1404       2023        Executive       Full-Time               Data Engineer
# 3616       2021     Intermediate       Full-Time               Data Engineer
# 3560       2021           Junior       Full-Time  Machine Learning Scientist
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1981  182750             USD         182750                 US  Fully-remote
# 2150   61000             EUR          64090                 DE     No-remote
# 1404  200000             USD         200000                 US     No-remote
# 3616  110000             USD         110000                 US  Fully-remote
# 3560  225000             USD         225000                 US  Fully-remote
#
#      company_location company_size
# 1981               US            M
# 2150               DE            M
# 1404               US            M
# 3616               US            L
# 3560               US            L

# %% [markdown]
# ### company_size

# %%
df['company_size'].unique()
# Out:
# array(['L', 'S', 'M'], dtype=object)

# %%
company_size = {'L': 'Large', 'M': 'Medium', 'S': 'Small'}
df['company_size'] = df['company_size'].map(company_size)

df.sample(5)
# Out:
#       work_year experience_level employment_type                   job_title  \
# 670        2023           Senior       Full-Time   Machine Learning Engineer
# 2824       2022           Senior       Full-Time  Machine Learning Scientist
# 2567       2022     Intermediate       Full-Time              Data Scientist
# 690        2023     Intermediate       Full-Time              Data Scientist
# 1226       2023           Senior       Full-Time               Data Engineer
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 670   120000             USD         120000                 US  Fully-remote
# 2824  193900             USD         193900                 US     No-remote
# 2567   84000             USD          84000                 BR  Fully-remote
# 690   100000             USD         100000                 US     No-remote
# 1226  133300             USD         133300                 US     No-remote
#
#      company_location company_size
# 670                US       Medium
# 2824               US       Medium
# 2567               BR       Medium
# 690                US       Medium
# 1226               US       Medium

# %% [markdown]
# ### remove unnecessary column

# %%
# the column salary_in_usd is the uniform for all salary, so salary and salary_currency is not used anymore for this analysis.
# drop salary and salary_currency
df.drop(columns=['salary', 'salary_currency'], inplace=True)

# %%
# rename column salary_in_usd
df.rename(columns={'salary_in_usd': 'salary'}, inplace=True)

# %%
# see the df
df.sample(5)
# Out:
#       work_year experience_level employment_type          job_title  salary  \
# 1728       2023     Intermediate       Full-Time  Research Engineer  120000
# 1837       2022           Senior       Full-Time      Data Engineer  120000
# 3749       2021           Senior       Full-Time    Data Specialist  165000
# 3533       2021           Junior       Full-Time       Data Analyst   90000
# 1009       2023           Senior       Full-Time       Data Analyst  152380
#
#      employee_residence  remote_ratio company_location company_size
# 1728                 US  Fully-remote               US       Medium
# 1837                 US     No-remote               US       Medium
# 3749                 US  Fully-remote               US        Large
# 3533                 US  Fully-remote               US        Small
# 1009                 US     No-remote               US       Medium

# %% [markdown]
# ## Export Clean Data

# %%
df.to_csv('ds_salary_clean.csv', index=False)

# %%
# check csv
df_clean = pd.read_csv("ds_salary_clean.csv")
df_clean.sample(5)
# Out:
#       work_year experience_level employment_type                job_title  \
# 1141       2023           Senior       Full-Time           Data Scientist
# 2998       2022           Senior       Full-Time            Data Engineer
# 3320       2022           Senior       Full-Time           Data Scientist
# 3530       2020     Intermediate       Full-Time  Data Science Consultant
# 490        2023           Senior       Full-Time            Data Engineer
#
#       salary employee_residence  remote_ratio company_location company_size
# 1141  126500                 US     No-remote               US       Medium
# 2998  154000                 US  Fully-remote               US       Medium
# 3320  176000                 US  Fully-remote               US       Medium
# 3530  103000                 US  Fully-remote               US        Large
# 490   128000                 US     No-remote               US       Medium
